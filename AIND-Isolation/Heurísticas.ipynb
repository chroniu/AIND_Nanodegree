# %%
Implementação Correta


    
# 1        
return - num_positions_filled(game, player)

# 2 
return num_positions_filled(game, game.get_opponent(player))

# 3 
return len(game.get_blank_spaces())/player_moves - num_positions_filled(game, player)


                        *************************                         
                             Playing Matches                              
                        *************************                         

 Match #   Opponent    AB_Improved   AB_Custom   AB_Custom_2  AB_Custom_3 
                        Won | Lost   Won | Lost   Won | Lost   Won | Lost 
    1       Random      10  |   0     2  |   8    10  |   0     7  |   3  
    2       MM_Open      7  |   3     1  |   9     5  |   5     5  |   5  
    3      MM_Center    10  |   0     1  |   9     6  |   4     9  |   1  
    4     MM_Improved    4  |   6     2  |   8     8  |   2     7  |   3  
    5       AB_Open      5  |   5     1  |   9     3  |   7     5  |   5  
    6      AB_Center     4  |   6     0  |  10     2  |   8     4  |   6  
    7     AB_Improved    4  |   6     2  |   8     5  |   5     5  |   5  
--------------------------------------------------------------------------
           Win Rate:      62.9%        12.9%        55.7%        60.0%    



----------------------------------------------


 Match #   Opponent    AB_Improved   AB_Custom   AB_Custom_2  AB_Custom_3 
                        Won | Lost   Won | Lost   Won | Lost   Won | Lost 
    1       Random      10  |   0     3  |   7     9  |   1    10  |   0  
    2       MM_Open      9  |   1     1  |   9     5  |   5     8  |   2  
    3      MM_Center     8  |   2     3  |   7     8  |   2     9  |   1  
    4     MM_Improved    9  |   1     1  |   9     6  |   4     8  |   2  
    5       AB_Open      5  |   5     1  |   9     3  |   7     8  |   2  
    6      AB_Center     6  |   4     2  |   8     5  |   5     6  |   4  
    7     AB_Improved    4  |   6     0  |  10     6  |   4     3  |   7  
--------------------------------------------------------------------------
           Win Rate:      72.9%        15.7%        60.0%        74.3%    


#1
return - num_positions_filled(game, player) + player_moves

#2 



return num_positions_filled(game, game.get_opponent(player)) - 
      num_positions_filled(game, player)


#3 
return len(game.get_blank_spaces())/player_moves - 
   num_positions_filled(game, player) + 
   len(game.get_blank_spaces())/opponent_moves

# %%
# segunda iteração


                        *************************                         
                             Playing Matches                              
                        *************************                         

 Match #   Opponent    AB_Improved   AB_Custom   AB_Custom_2  AB_Custom_3 
                        Won | Lost   Won | Lost   Won | Lost   Won | Lost 
    1       Random      10  |   0     9  |   1     4  |   6     9  |   1  
    2       MM_Open      8  |   2     9  |   1     0  |  10     7  |   3  
    3      MM_Center     9  |   1     9  |   1     2  |   8    10  |   0  
    4     MM_Improved    7  |   3     9  |   1     0  |  10     7  |   3  
    5       AB_Open      5  |   5     5  |   5     0  |  10     4  |   6  
    6      AB_Center     6  |   4     6  |   4     1  |   9     5  |   5  
    7     AB_Improved    4  |   6     5  |   5     1  |   9     5  |   5  
--------------------------------------------------------------------------
           Win Rate:      70.0%        74.3%        11.4%        67.1%    
        
        

#1
return player_moves/len(game.get_blank_spaces())


#2
return player_moves/len(game.get_blank_spaces()) - 
num_positions_filled(game, player) +  opponent_moves/len(game.get_blank_spaces())

#3

return len(game.get_blank_spaces())/player_moves - 
   num_positions_filled(game, player) + 
   len(game.get_blank_spaces())/opponent_moves








-------------------------------------------------------------
# 1



 Match #   Opponent    AB_Improved   AB_Custom   AB_Custom_2  AB_Custom_3 
                        Won | Lost   Won | Lost   Won | Lost   Won | Lost 
    1       Random       9  |   1    10  |   0     1  |   9     9  |   1  
    2       MM_Open      7  |   3     9  |   1     4  |   6    10  |   0  
    3      MM_Center     9  |   1    10  |   0     5  |   5     9  |   1  
    4     MM_Improved    7  |   3     8  |   2     0  |  10     9  |   1  
    5       AB_Open      7  |   3     4  |   6     3  |   7     3  |   7  
    6      AB_Center     5  |   5     8  |   2     0  |  10     4  |   6  
    7     AB_Improved    5  |   5     5  |   5     0  |  10     5  |   5  
--------------------------------------------------------------------------
           Win Rate:      70.0%        77.1%        18.6%        70.0%    

#1        
return player_moves/len(game.get_blank_spaces())


# 2
if(game.get_player_location(player) == (-1, -1)):
    return len(game.get_legal_moves(player))
        
return player_moves/len(game.get_blank_spaces()) - 
num_positions_filled(game, player) +  opponent_moves/len(game.get_blank_spaces())




#3
if(game.get_player_location(player) == (-1, -1)):
    return len(game.get_legal_moves(player))


return len(game.get_blank_spaces())/player_moves - 
   num_positions_filled(game, player) + 
   len(game.get_blank_spaces())/opponent_moves
